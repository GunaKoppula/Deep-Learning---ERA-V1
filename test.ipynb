# %%
import requests
from urllib3.exceptions import InsecureRequestWarning
from urllib3 import disable_warnings

# %%
API_key = '2ba56868930ce82ca35aadb64bd40c95'
city_name = 'vizag'

# disable_warnings(InsecureRequestWarning)

# page = requests.get('http://facebook.com', verify=False)



# r = requests.get(f"https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={API_key}", verify=False)
r = requests.get(f"https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={API_key}", verify=False)
# print(r.content)

json_object = r.json()
print(json_object)
# Out:
# {'cod': '404', 'message': 'city not found'}
# C:\Users\gunak\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.openweathermap.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
message = json_object.get('message', '')
message
# Out:
# 'city not found'

# %%
r.status_code
# Out:
# 404

# %%
json_object['main']['temp']
# Out:
# 283.81

# %%
api_key = '2ba56868930ce82ca35aadb64bd40c95'
cityName = 'london'

# %%
url = f'http://api.openweathermap.org/data/2.5/weather?q={cityName}&appid={api_key}&units=metric'
response = requests.get(url)
data = response.json()

# %%
from datetime import datetime

# %%
# Get the current date and time
now = datetime.now()

# Format the date and time
formatted_date = now.strftime("%A, %d %B")  # e.g., "Tuesday, 22 October"
formatted_time = now.strftime("%H:%M")      # e.g., "17:29"

# Print the results
print("Date:", formatted_date)
print("Time:", formatted_time)
# Out:
# Date: Tuesday, 22 October
# Time: 17:30

# %%
from timezonefinder import TimezoneFinder
import pytz

# %%
def get_datetime_from_coordinates(latitude, longitude):
    # Find the timezone using coordinates
    tf = TimezoneFinder()
    timezone_str = tf.timezone_at(lat=latitude, lng=longitude)
    
    if timezone_str is None:
        return "Timezone not found for the given coordinates."

    # Get the current time in the specified timezone
    tz = pytz.timezone(timezone_str)
    now = datetime.now(tz)

    # Format the date and time
    formatted_date = now.strftime("%A, %d %B")
    formatted_time = now.strftime("%H:%M")

    return formatted_date, formatted_time

# Calculate Dew Point
def calculate_dew_point(temp, humidity):
    return temp - (100 - humidity) / 5

# %%
data
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 15.59,
#   'feels_like': 15.22,
#   'temp_min': 14.2,
#   'temp_max': 16.62,
#   'pressure': 1028,
#   'humidity': 77,
#   'sea_level': 1028,
#   'grnd_level': 1024},
#  'visibility': 10000,
#  'wind': {'speed': 6.17, 'deg': 240},
#  'clouds': {'all': 75},
#  'dt': 1729598869,
#  'sys': {'type': 2,
#   'id': 2075535,
#   'country': 'GB',
#   'sunrise': 1729579011,
#   'sunset': 1729615961},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
lat = data['coord']['lat']
lon = data['coord']['lon']
date, time = get_datetime_from_coordinates(lat, lon)
temp = data['main']['temp']
humidity = data['main']['humidity']
dew_point = calculate_dew_point(temp, humidity)
cloud_cover = data['clouds']['all']

# Determine weather condition based on cloud cover
if cloud_cover <= 20:
    weather_condition = "Clear"
elif cloud_cover <= 50:
    weather_condition = "Partly Cloudy"
elif cloud_cover <= 80:
    weather_condition = "Cloudy"
else:
    weather_condition = "Overcast"

print({
    'country': data['name'],
    'date': date,
    'time': time,
    'temperature': temp,
    'temp_min': data['main']['temp_min'],
    'temp_max': data['main']['temp_max'],
    'humidity': humidity,
    'feels_like': data['main']['feels_like'],
    'pressure': data['main']['pressure'],
    'visibility': data['visibility'],
    'wind_speed' : data['wind']['speed'],
    'dew_point': dew_point,
    'weather_condition' : weather_condition
})
# Out:
# {'country': 'London', 'date': 'Tuesday, 22 October', 'time': '13:28', 'temperature': 15.59, 'temp_min': 14.2, 'temp_max': 16.62, 'humidity': 77, 'feels_like': 15.22, 'pressure': 1028, 'visibility': 10000, 'wind_speed': 6.17, 'dew_point': 10.99, 'weather_condition': 'Cloudy'}

# %%
r = requests.get(f"https://api.openweathermap.org/data/2.5/weather?q={cityName}&appid={weatherApiKey}", verify=False)
# Out:
# C:\Users\k.guna.satya.sri\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.openweathermap.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
weatherApiKey = '2ba56868930ce82ca35aadb64bd40c95'
cityName = "london"
r = requests.get(f"https://api.openweathermap.org/data/2.5/weather?q={cityName}&appid={weatherApiKey}", verify=False)
# Out:
# C:\Users\k.guna.satya.sri\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.openweathermap.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
r = requests.get(f"https://api.openweathermap.org/data/2.5/forecast?q={cityName}&appid={weatherApiKey}", verify=False)
# Out:
# C:\Users\k.guna.satya.sri\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.openweathermap.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
r = requests.get(f"https://api.openweathermap.org/data/2.5/alerts?q={cityName}&appid={weatherApiKey}")

# %%
r
# Out:
# <Response [404]>

# %%
eval(r.text)
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1725894000,
#    'main': {'temp': 289.42,
#     'feels_like': 288.96,
#     'temp_min': 289.42,
#     'temp_max': 289.5,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 71,
#     'temp_kf': -0.08},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.3, 'deg': 312, 'gust': 7.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-09 15:00:00'},
#   {'dt': 1725904800,
#    'main': {'temp': 289.35,
#     'feels_like': 288.59,
#     'temp_min': 289.33,
#     'temp_max': 289.35,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 60,
#     'temp_kf': 0.02},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
# ...
